# %%
import matplotlib.pyplot as plt

vx = (1, 2, 3)
vy = (2, 5, 4)

plt.scatter(vx, vy)
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import matplotlib.pyplot as plt

# import japanize_matplotlib

htemp = (
    22.4,
    22.8,
    22.7,
    14.9,
    20.9,
    24.7,
    22.6,
    27.4,
    27.9,
    29.1,
    16.9,
    24.7,
    22.3,
    25.6,
)

plt.hist(htemp, color="red", bins=8, range=(10, 34))
plt.title("2023年5月の千葉市の最高温度の日数")
plt.xlabel("温度")
plt.ylabel("日数")
plt.show()

# %%
import matplotlib.pyplot as plt

history = (82, 75, 40, 73, 65, 100, 78, 99, 71, 83)
informatics = (30, 90, 20, 22, 45, 81, 66, 78, 45, 100)

kamokumei = (history, informatics)
kamokumei_en = ("history", "informatics")
fig, ax = plt.subplots()

bp = ax.boxplot(kamokumei)
ax.set_xticklabels(kamokumei_en)

plt.title("score")
plt.grid()
plt.show()
